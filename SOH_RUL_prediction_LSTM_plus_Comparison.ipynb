# %% [markdown]
# **Data to CSV**

# %%
# from scipy.io import loadmat
# import os
# import pandas as pd

# def load_data(mat_path, battery):
#     mat = loadmat(mat_path)
#     counter = 0
#     dataset = []

#     for i in range(len(mat[battery][0, 0]['cycle'][0])):
#         row = mat[battery][0, 0]['cycle'][0, i]
#         if row['type'][0] == 'discharge':
#             ambient_temperature = row['ambient_temperature'][0][0]
#             data = row['data']
#             capacity = data[0][0]['Capacity'][0][0]
#             for j in range(len(data[0][0]['Voltage_measured'][0])):
#                 voltage_measured = data[0][0]['Voltage_measured'][0][j]
#                 current_measured = data[0][0]['Current_measured'][0][j]
#                 temperature_measured = data[0][0]['Temperature_measured'][0][j]
#                 current_load = data[0][0]['Current_load'][0][j]
#                 voltage_load = data[0][0]['Voltage_load'][0][j]
#                 time = data[0][0]['Time'][0][j]
#                 dataset.append([counter + 1, ambient_temperature, capacity,
#                                 voltage_measured, current_measured,
#                                 temperature_measured, current_load,
#                                 voltage_load, time])
#             counter = counter + 1

#     return pd.DataFrame(data=dataset,
#                        columns=['cycle', 'ambient_temperature',
#                                 'capacity', 'voltage_measured',
#                                 'current_measured', 'temperature_measured',
#                                 'current_load', 'voltage_load', 'time'])

# def calculate_RUL(df):
#     eol_cycle = df['cycle'].max()

#     df['RUL'] = eol_cycle - df['cycle']

#     return df

# datasets = ["B0005", "B0006", "B0007", "B0018"]
# for name in datasets:
#     dataset = load_data(f'{name}.mat', name)
#     dataset_with_rul = calculate_RUL(dataset)

#     csv_filename = f'{name}_discharge.csv'
#     dataset_with_rul.to_csv(csv_filename, index=False)

# %% [markdown]
# **Import Libaraies**

# %%
import datetime
import numpy as np
import pandas as pd
from scipy.io import loadmat
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn import metrics
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import (
    Input,
    LSTM,
    Conv1D,
    BatchNormalization,
    Activation,
    Add,
    SpatialDropout1D,
    GlobalAveragePooling1D,
    Dropout,
    Dense,
)
from sklearn.metrics import mean_squared_error, mean_absolute_error
import random as rnd

# %%
# Change this to "LSTM" or "TCN" to select the model family for training.
MODEL_ARCHITECTURE = "LSTM"

def build_lstm_model(input_shape, lstm_units=100, dense_units=50, dropout_rate=0.3):
    inputs = Input(shape=input_shape)
    x = LSTM(lstm_units, return_sequences=True)(inputs)
    x = Dropout(dropout_rate)(x)
    x = LSTM(lstm_units, return_sequences=True)(x)
    x = Dropout(dropout_rate)(x)
    x = LSTM(lstm_units)(x)
    x = Dropout(dropout_rate)(x)
    x = Dense(dense_units, activation='relu')(x)
    x = Dropout(dropout_rate)(x)
    outputs = Dense(1, activation='linear')(x)
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def residual_tcn_block(x, filters, kernel_size, dilation_rate, dropout_rate):
    residual = x
    x = Conv1D(
        filters,
        kernel_size,
        padding='causal',
        dilation_rate=dilation_rate,
        kernel_initializer='he_normal',
    )(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = SpatialDropout1D(dropout_rate)(x)
    x = Conv1D(
        filters,
        kernel_size,
        padding='causal',
        dilation_rate=dilation_rate,
        kernel_initializer='he_normal',
    )(x)
    x = BatchNormalization()(x)

    if residual.shape[-1] != filters:
        residual = Conv1D(filters, 1, padding='same', kernel_initializer='he_normal')(residual)

    x = Add()([x, residual])
    return Activation('relu')(x)

def build_tcn_model(
    input_shape,
    filters=100,
    kernel_size=3,
    dropout_rate=0.2,
    dense_units=50,
    dilation_rates=(1, 2, 4),
    head_dropout_rate=0.0,
):
    inputs = Input(shape=input_shape)
    x = inputs
    for dilation_rate in dilation_rates:
        x = residual_tcn_block(x, filters, kernel_size, dilation_rate, dropout_rate)
    x = GlobalAveragePooling1D()(x)
    if head_dropout_rate:
        x = Dropout(head_dropout_rate)(x)
    x = Dense(dense_units, activation='relu')(x)
    if head_dropout_rate:
        x = Dropout(head_dropout_rate)(x)
    outputs = Dense(1, activation='linear')(x)
    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def build_model(architecture, input_shape, **kwargs):
    architecture = architecture.upper()
    if architecture == 'LSTM':
        return build_lstm_model(input_shape, **kwargs)
    if architecture == 'TCN':
        return build_tcn_model(input_shape, **kwargs)
    raise ValueError(f"Unsupported architecture: {architecture}")

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Data preprocessing to divide the data into sequences of 10 observations in each cycle, the sequence have overlap with eachother.

# %%
def generate_sequences(data, window_size):
    X, y_capacity, y_RUL, y_SOH = [], [], [], []
    cyclic_RUL_x, cyclic_RUL_y = [], []

    cycles = data['cycle'].unique()
    initial_capacity = data.iloc[0]['capacity']

    # Normalize all 'capacity' values by the first row's 'capacity' value
    data['SOH'] = data['capacity'] / initial_capacity

    # dividing the data of each cycle into sequences
    for cycle in cycles:
        cycle_data = data[data['cycle'] == cycle]
        cycle_observations = []
        num_rows = len(cycle_data)

        if num_rows >= window_size:
            for start in range(num_rows - window_size + 1):
                end = start + window_size

                features = cycle_data.iloc[start:end].drop(['cycle', 'capacity', 'RUL', 'SOH'], axis=1).values # Exclude 'cycle', 'capacity', 'RUL', 'SOH'
                target_capacity = cycle_data.iloc[end-1, cycle_data.columns.get_loc('capacity')] # Capacity target
                target_SOH = cycle_data.iloc[end-1, cycle_data.columns.get_loc('SOH')] # SOH target
                target_RUL = cycle_data.iloc[end-1, cycle_data.columns.get_loc('RUL')] # RUL target
                cycle_observations.append(features)
                X.append(features)
                y_capacity.append(target_capacity)
                y_SOH.append(target_SOH)
                y_RUL.append(target_RUL)

            cyclic_RUL_x.append(y_capacity[-1])
            cyclic_RUL_y.append(y_RUL[-1])

    return np.array(X), np.array(y_capacity), np.array(y_SOH), np.array(y_RUL), np.array(cyclic_RUL_x), np.array(cyclic_RUL_y)

# %%
file_path_0005 = "/content/drive/MyDrive/TProject/csv/B0005_discharge.csv"
file_path_0006 = "/content/drive/MyDrive/TProject/csv/B0006_discharge.csv"
file_path_0007 = "/content/drive/MyDrive/TProject/csv/B0007_discharge.csv"
file_path_0018 = "/content/drive/MyDrive/TProject/csv/B0018_discharge.csv"

# reading the data files
data_0005 = pd.read_csv(file_path_0005)
data_0006 = pd.read_csv(file_path_0006)
data_0007 = pd.read_csv(file_path_0007)
data_0018 = pd.read_csv(file_path_0018)

# making the sequnces for each data file
X_0005, y_capacit_0005, y_SOH_0005, y_RUL_0005, cyclic_RUL_x_0005, cyclic_RUL_y_0005 = generate_sequences(data_0005, 10)
X_0006, y_capacit_0006, y_SOH_0006,  y_RUL_0006, cyclic_RUL_x_0006, cyclic_RUL_y_0006 = generate_sequences(data_0006, 10)
X_0007, y_capacit_0007, y_SOH_0007,  y_RUL_0007, cyclic_RUL_x_0007, cyclic_RUL_y_0007 = generate_sequences(data_0007, 10)
X_0018, y_capacit_0018, y_SOH_0018,  y_RUL_0018, cyclic_RUL_x_0018, cyclic_RUL_y_0018 = generate_sequences(data_0018, 10)

# %%
# concatenating the data
X = np.concatenate((X_0005, X_0006, X_0007, X_0018), axis=0)
y_capacity = np.concatenate((y_capacit_0005, y_capacit_0006, y_capacit_0007, y_capacit_0018), axis=0)
y_SOH = np.concatenate((y_SOH_0005, y_SOH_0006, y_SOH_0007, y_SOH_0018), axis=0)
y_RUL = np.concatenate((y_RUL_0005, y_RUL_0006, y_RUL_0007, y_RUL_0018), axis=0)
cyclic_RUL_x = np.concatenate((cyclic_RUL_x_0005, cyclic_RUL_x_0006, cyclic_RUL_x_0007, cyclic_RUL_x_0018), axis=0)
cyclic_RUL_y = np.concatenate((cyclic_RUL_y_0005, cyclic_RUL_y_0006, cyclic_RUL_y_0007, cyclic_RUL_y_0018), axis=0)

# %% [markdown]
# # Predicting SOH/Capacity

# %% [markdown]
# ## predicting raw capacity

# %% [markdown]
# This step is only added for the sake of comparing our method with baselines since they predict raw capacity rather than SOH, and this model is not part of our pipeline

# %%
# data split into train, test, validation
X_capacity_train, X_capacity_testval, y_capacity_train, y_capacity_testval = train_test_split(
    X, y_capacity, test_size=0.2, random_state=42
)

X_capacity_test, X_capacity_validation, y_capacity_test, y_capacity_validation = train_test_split(
    X_capacity_testval, y_capacity_testval, test_size=0.5, random_state=42
)

# %%
# architecture of model
time_steps = X_capacity_train.shape[1]
features = X_capacity_train.shape[2]

if MODEL_ARCHITECTURE == "LSTM":
    model = build_model(
        MODEL_ARCHITECTURE,
        (time_steps, features),
        lstm_units=100,
        dropout_rate=0.2,
        dense_units=50,
    )
else:  # TCN
    model = build_model(
        MODEL_ARCHITECTURE,
        (time_steps, features),
        filters=100,
        kernel_size=3,
        dropout_rate=0.2,
        dense_units=50,
        dilation_rates=(1, 2, 4),
        head_dropout_rate=0.0,
    )

# %%
# training and saving the model
history = model.fit(X_capacity_train, y_capacity_train, epochs=20, validation_data=(X_capacity_validation, y_capacity_validation), verbose=1)
model.save(f'/content/drive/MyDrive/TProject/models/Raw_Capacity_{MODEL_ARCHITECTURE}.h5')
# Out:
# Epoch 1/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 159s 34ms/step - loss: 0.0496 - val_loss: 0.0184
# Epoch 2/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 151s 33ms/step - loss: 0.0198 - val_loss: 0.0128
# Epoch 3/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 149s 33ms/step - loss: 0.0158 - val_loss: 0.0143
# Epoch 4/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 154s 34ms/step - loss: 0.0148 - val_loss: 0.0139
# Epoch 5/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 149s 33ms/step - loss: 0.0146 - val_loss: 0.0130
# Epoch 6/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 152s 34ms/step - loss: 0.0142 - val_loss: 0.0128
# Epoch 7/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 149s 33ms/step - loss: 0.0139 - val_loss: 0.0172
# Epoch 8/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 207s 34ms/step - loss: 0.0132 - val_loss: 0.0119
# Epoch 9/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 198s 33ms/step - loss: 0.0139 - val_loss: 0.0136
# Epoch 10/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 149s 33ms/step - loss: 0.0138 - val_loss: 0.0109
# Epoch 11/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 153s 34ms/step - loss: 0.0126 - val_loss: 0.0188
# Epoch 12/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 200s 34ms/step - loss: 0.0118 - val_loss: 0.0126
# Epoch 13/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 148s 33ms/step - loss: 0.0132 - val_loss: 0.0128
# Epoch 14/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 148s 33ms/step - loss: 0.0132 - val_loss: 0.0120
# Epoch 15/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 148s 33ms/step - loss: 0.0130 - val_loss: 0.0143
# Epoch 16/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 149s 33ms/step - loss: 0.0129 - val_loss: 0.0129
# Epoch 17/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 202s 33ms/step - loss: 0.0114 - val_loss: 0.0119
# Epoch 18/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 193s 31ms/step - loss: 0.0115 - val_loss: 0.0096
# Epoch 19/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 142s 31ms/step - loss: 0.0105 - val_loss: 0.0129
# Epoch 20/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 145s 32ms/step - loss: 0.0106 - val_loss: 0.0125
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### testing

# %%
# loading the model
cap_model_tcn = load_model(f'/content/drive/MyDrive/TProject/models/Raw_Capacity_{MODEL_ARCHITECTURE}.h5')
cap_model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 10, 7)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 10, 100)   │      2,200 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 100)   │        400 │ conv1d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 10, 100)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_3 │ (None, 10, 100)   │          0 │ activation_6[0][… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 10, 100)   │     30,100 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 100)   │        400 │ conv1d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 10, 100)   │        800 │ input_layer_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 10, 100)   │          0 │ batch_normalizat… │
# │                     │                   │            │ conv1d_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 10, 100)   │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 10, 100)   │     30,100 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 100)   │        400 │ conv1d_10[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 10, 100)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_4 │ (None, 10, 100)   │          0 │ activation_8[0][… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 10, 100)   │     30,100 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 100)   │        400 │ conv1d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 10, 100)   │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 10, 100)   │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_12 (Conv1D)  │ (None, 10, 100)   │     30,100 │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 100)   │        400 │ conv1d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 10, 100)   │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout1d_5 │ (None, 10, 100)   │          0 │ activation_10[0]… │
# │ (SpatialDropout1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_13 (Conv1D)  │ (None, 10, 100)   │     30,100 │ spatial_dropout1… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 100)   │        400 │ conv1d_13[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_5 (Add)         │ (None, 10, 100)   │          0 │ batch_normalizat… │
# │                     │                   │            │ activation_9[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 10, 100)   │          0 │ add_5[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 100)       │          0 │ activation_11[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 50)        │      5,050 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │         51 │ dense_2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 161,003 (628.92 KB)
#  Trainable params: 159,801 (624.22 KB)
#  Non-trainable params: 1,200 (4.69 KB)
#  Optimizer params: 2 (12.00 B)

# %%
# testing the accuracy of model on test dataset
predicted_y = cap_model.predict(X_capacity_test)
true_y = y_capacity_test

mse = mean_squared_error(true_y, predicted_y)
mae = mean_absolute_error(true_y, predicted_y)
rmse = np.sqrt(mse)

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)

plt.figure(figsize=(10, 5))

plt.plot(true_y, label='True Values')

plt.plot(predicted_y, label='Predicted Values')

plt.title('Comparison of True and Predicted Values')
plt.xlabel('Index')
plt.ylabel('Capacity')
plt.legend()
plt.show()
# Out:
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step
# Mean Squared Error: 0.02397379854654629
# Mean Absolute Error: 0.12976239661222153
# Root Mean Squared Error: 0.15483474592786428

# %% [markdown]
# ## predicting SOH (main method)

# %% [markdown]
# This is for predicting the SOH (currecnt capacity / initial capacity) which is used as input for the RUL model.

# %%
# spliting data into train, test, validation
X_SOH_train, X_SOH_testval, y_SOH_train, y_SOH_testval = train_test_split(
    X, y_SOH, test_size=0.2, random_state=42
)

X_SOH_test, X_SOH_validation, y_SOH_test, y_SOH_validation = train_test_split(
    X_SOH_testval, y_SOH_testval, test_size=0.5, random_state=42
)

# %%
# architecture of the model
time_steps = X_SOH_train.shape[1]
features = X_SOH_train.shape[2]

if MODEL_ARCHITECTURE == "LSTM":
    model = build_model(
        MODEL_ARCHITECTURE,
        (time_steps, features),
        lstm_units=100,
        dropout_rate=0.2,
        dense_units=50,
    )
else:  # TCN
    model = build_model(
        MODEL_ARCHITECTURE,
        (time_steps, features),
        filters=100,
        kernel_size=3,
        dropout_rate=0.2,
        dense_units=50,
        dilation_rates=(1, 2, 4),
        head_dropout_rate=0.0,
    )

# %%
# training the model
history = model.fit(X_SOH_train, y_SOH_train, epochs=20, validation_data=(X_SOH_validation, y_SOH_validation), verbose=1)
model.save(f'/content/drive/MyDrive/TProject/models/SOH_{MODEL_ARCHITECTURE}.h5')
# Out:
# Epoch 1/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 155s 33ms/step - loss: 0.0158 - val_loss: 0.0113
# Epoch 2/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 148s 33ms/step - loss: 0.0112 - val_loss: 0.0091
# Epoch 3/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 149s 33ms/step - loss: 0.0102 - val_loss: 0.0091
# Epoch 4/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 145s 32ms/step - loss: 0.0096 - val_loss: 0.0109
# Epoch 5/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 146s 32ms/step - loss: 0.0097 - val_loss: 0.0108
# Epoch 6/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 151s 34ms/step - loss: 0.0111 - val_loss: 0.0113
# Epoch 7/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 201s 33ms/step - loss: 0.0106 - val_loss: 0.0091
# Epoch 8/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 149s 33ms/step - loss: 0.0108 - val_loss: 0.0113
# Epoch 9/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 147s 33ms/step - loss: 0.0113 - val_loss: 0.0111
# Epoch 10/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 147s 33ms/step - loss: 0.0102 - val_loss: 0.0091
# Epoch 11/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 146s 33ms/step - loss: 0.0102 - val_loss: 0.0110
# Epoch 12/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 146s 32ms/step - loss: 0.0104 - val_loss: 0.0091
# Epoch 13/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 145s 32ms/step - loss: 0.0101 - val_loss: 0.0110
# Epoch 14/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 148s 33ms/step - loss: 0.0100 - val_loss: 0.0091
# Epoch 15/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 150s 33ms/step - loss: 0.0093 - val_loss: 0.0091
# Epoch 16/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 148s 33ms/step - loss: 0.0093 - val_loss: 0.0091
# Epoch 17/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 150s 33ms/step - loss: 0.0108 - val_loss: 0.0108
# Epoch 18/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 149s 33ms/step - loss: 0.0099 - val_loss: 0.0091
# Epoch 19/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 201s 33ms/step - loss: 0.0102 - val_loss: 0.0091
# Epoch 20/20
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 148s 33ms/step - loss: 0.0093 - val_loss: 0.0091
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### Testing

# %%
# loading the model
SOH_model = load_model(f'/content/drive/MyDrive/TProject/models/SOH_{MODEL_ARCHITECTURE}.h5')
SOH_model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 10, 7)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 10, 100)        │        43,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 10, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 10, 100)        │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 10, 100)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 100)            │        80,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 209,103 (816.81 KB)
#  Trainable params: 209,101 (816.80 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
# testing the accuracy of model on thw test dataset
predicted_y = SOH_model.predict(X_SOH_test)
true_y = y_SOH_test

mse = mean_squared_error(true_y, predicted_y)
mae = mean_absolute_error(true_y, predicted_y)
rmse = np.sqrt(mse)

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)

plt.figure(figsize=(10, 5))

plt.plot(true_y, label='True Values')

plt.plot(predicted_y, label='Predicted Values')

plt.title('Comparison of True and Predicted Values Testing set')
plt.xlabel('Index')
plt.ylabel('SOH')
plt.legend()
plt.show()
# Out:
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step
# Mean Squared Error: 0.009075696110805359
# Mean Absolute Error: 0.07741847315450322
# Root Mean Squared Error: 0.09526644798041627

# %%
# testing the accuracy of model on train dataset
predicted_y = SOH_model.predict(X_SOH_train)
true_y = y_SOH_train

mse = mean_squared_error(true_y, predicted_y)
mae = mean_absolute_error(true_y, predicted_y)
rmse = np.sqrt(mse)

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)

plt.figure(figsize=(10, 5))

plt.plot(true_y, label='True Values')

plt.plot(predicted_y, label='Predicted Values')

plt.title('Comparison of True and Predicted Values Training set')
plt.xlabel('Index')
plt.ylabel('SOH')
plt.legend()
plt.show()
# Out:
# 4500/4500 ━━━━━━━━━━━━━━━━━━━━ 45s 10ms/step
# Mean Squared Error: 0.009275392894242852
# Mean Absolute Error: 0.07823249604879416
# Root Mean Squared Error: 0.09630884120496339

# %% [markdown]
# # Predicting RUL

# %%
# reshaping the cyclic_RUL_x data so that each element is a numpy array
cyclic_RUL_x_reshaped = np.empty((cyclic_RUL_x.shape[0], 1))
for i in range(cyclic_RUL_x.shape[0]):
  cyclic_RUL_x_reshaped[i] = np.array([cyclic_RUL_x[i]])

# %%
# scaling the RUL values between 0 and 1
scaler = MinMaxScaler()
scaled_rul = scaler.fit_transform(cyclic_RUL_y.reshape(-1, 1))

# %%
# generating sequntial data for RUL prediction given SOH, here we use sequences of 3 cycles (not observation, note that the SOH and RUL are constant in each cycle)
def generate_sequences_RUL(capacity, RUL_GT, window_size):
  X, y_RUL = [], []
  for start in range(capacity.shape[0] - window_size + 1):
    end = start + window_size

    features = capacity[start:end]
    target_RUL = RUL_GT[end-1]
    X.append(features)
    y_RUL.append(target_RUL)

  return np.array(X), np.array(y_RUL)

# %%
X_for_RUL, y_RUL = generate_sequences_RUL(cyclic_RUL_x_reshaped, scaled_rul, 3)

# %%
# spliting the data into train, test, and validation
X_RUL_train, X_RUL_testval, y_RUL_train, y_RUL_testval = train_test_split(
    X_for_RUL, y_RUL, test_size=0.1, random_state=42
)

X_RUL_test, X_RUL_validation, y_RUL_test, y_RUL_validation = train_test_split(
    X_RUL_testval, y_RUL_testval, test_size=0.5, random_state=42
)

# %%
# architecture of the model
if MODEL_ARCHITECTURE == "LSTM":
    model = build_model(
        MODEL_ARCHITECTURE,
        (X_RUL_train.shape[1], 1),
        lstm_units=200,
        dropout_rate=0.3,
        dense_units=50,
    )
else:
    model = build_model(
        MODEL_ARCHITECTURE,
        (X_RUL_train.shape[1], 1),
        filters=128,
        kernel_size=2,
        dropout_rate=0.3,
        dense_units=50,
        dilation_rates=(1, 2, 4),
        head_dropout_rate=0.3,
    )

# %%
# training and saving the model
history = model.fit(X_RUL_train, y_RUL_train, epochs=200, validation_data=(X_RUL_validation, y_RUL_validation), verbose=1)
model.save(f'/content/drive/MyDrive/TProject/models/RUL_{MODEL_ARCHITECTURE}.h5')
# Out:
# Epoch 1/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 9s 76ms/step - loss: 0.1255 - val_loss: 0.0725
# Epoch 2/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0695 - val_loss: 0.0438
# Epoch 3/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0643 - val_loss: 0.0416
# Epoch 4/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0534 - val_loss: 0.0235
# Epoch 5/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0385 - val_loss: 0.0123
# Epoch 6/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0276 - val_loss: 0.0110
# Epoch 7/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0250 - val_loss: 0.0066
# Epoch 8/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0272 - val_loss: 0.0138
# Epoch 9/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.0214 - val_loss: 0.0094
# Epoch 10/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0206 - val_loss: 0.0058
# Epoch 11/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0225 - val_loss: 0.0067
# Epoch 12/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0221 - val_loss: 0.0060
# Epoch 13/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0199 - val_loss: 0.0070
# Epoch 14/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0222 - val_loss: 0.0182
# Epoch 15/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0203 - val_loss: 0.0100
# Epoch 16/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0208 - val_loss: 0.0059
# Epoch 17/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0192 - val_loss: 0.0072
# Epoch 18/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0195 - val_loss: 0.0068
# Epoch 19/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0189 - val_loss: 0.0060
# Epoch 20/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0201 - val_loss: 0.0089
# Epoch 21/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0175 - val_loss: 0.0057
# Epoch 22/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0186 - val_loss: 0.0120
# Epoch 23/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0206 - val_loss: 0.0061
# Epoch 24/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0191 - val_loss: 0.0133
# Epoch 25/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0193 - val_loss: 0.0167
# Epoch 26/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0192 - val_loss: 0.0163
# Epoch 27/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0204 - val_loss: 0.0073
# Epoch 28/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0214 - val_loss: 0.0118
# Epoch 29/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0220 - val_loss: 0.0156
# Epoch 30/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0214 - val_loss: 0.0069
# Epoch 31/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0168 - val_loss: 0.0103
# Epoch 32/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0172 - val_loss: 0.0087
# Epoch 33/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0155 - val_loss: 0.0061
# Epoch 34/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0171 - val_loss: 0.0058
# Epoch 35/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0171 - val_loss: 0.0058
# Epoch 36/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0165 - val_loss: 0.0113
# Epoch 37/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0174 - val_loss: 0.0058
# Epoch 38/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0166 - val_loss: 0.0057
# Epoch 39/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0163 - val_loss: 0.0070
# Epoch 40/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0148 - val_loss: 0.0060
# Epoch 41/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 0.0160 - val_loss: 0.0086
# Epoch 42/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0160 - val_loss: 0.0068
# Epoch 43/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0146 - val_loss: 0.0059
# Epoch 44/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0159 - val_loss: 0.0058
# Epoch 45/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0157 - val_loss: 0.0069
# Epoch 46/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0148 - val_loss: 0.0059
# Epoch 47/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0166 - val_loss: 0.0058
# Epoch 48/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0151 - val_loss: 0.0060
# Epoch 49/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0142 - val_loss: 0.0058
# Epoch 50/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0138 - val_loss: 0.0062
# Epoch 51/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0144 - val_loss: 0.0058
# Epoch 52/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0152 - val_loss: 0.0063
# Epoch 53/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 0.0142 - val_loss: 0.0083
# Epoch 54/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0147 - val_loss: 0.0060
# Epoch 55/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0153 - val_loss: 0.0060
# Epoch 56/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0146 - val_loss: 0.0087
# Epoch 57/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.0135 - val_loss: 0.0074
# Epoch 58/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 0.0134 - val_loss: 0.0072
# Epoch 59/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 0.0137 - val_loss: 0.0060
# Epoch 60/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0131 - val_loss: 0.0065
# Epoch 61/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0136 - val_loss: 0.0064
# Epoch 62/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0137 - val_loss: 0.0075
# Epoch 63/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0139 - val_loss: 0.0065
# Epoch 64/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0135 - val_loss: 0.0073
# Epoch 65/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0141 - val_loss: 0.0076
# Epoch 66/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0129 - val_loss: 0.0067
# Epoch 67/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0122 - val_loss: 0.0079
# Epoch 68/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0139 - val_loss: 0.0088
# Epoch 69/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0145 - val_loss: 0.0067
# Epoch 70/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0134 - val_loss: 0.0071
# Epoch 71/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0124 - val_loss: 0.0084
# Epoch 72/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0119 - val_loss: 0.0098
# Epoch 73/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0123 - val_loss: 0.0068
# Epoch 74/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0119 - val_loss: 0.0066
# Epoch 75/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 0.0124 - val_loss: 0.0068
# Epoch 76/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0125 - val_loss: 0.0067
# Epoch 77/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0128 - val_loss: 0.0064
# Epoch 78/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0119 - val_loss: 0.0089
# Epoch 79/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0144 - val_loss: 0.0072
# Epoch 80/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0139 - val_loss: 0.0070
# Epoch 81/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0122 - val_loss: 0.0092
# Epoch 82/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.0117 - val_loss: 0.0067
# Epoch 83/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0112 - val_loss: 0.0073
# Epoch 84/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0118 - val_loss: 0.0089
# Epoch 85/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0127 - val_loss: 0.0089
# Epoch 86/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0113 - val_loss: 0.0066
# Epoch 87/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0114 - val_loss: 0.0089
# Epoch 88/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0111 - val_loss: 0.0068
# Epoch 89/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0109 - val_loss: 0.0066
# Epoch 90/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0109 - val_loss: 0.0075
# Epoch 91/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0107 - val_loss: 0.0068
# Epoch 92/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0105 - val_loss: 0.0068
# Epoch 93/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0111 - val_loss: 0.0097
# Epoch 94/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0128 - val_loss: 0.0082
# Epoch 95/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0106 - val_loss: 0.0077
# Epoch 96/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0113 - val_loss: 0.0079
# Epoch 97/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0103 - val_loss: 0.0070
# Epoch 98/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0112 - val_loss: 0.0072
# Epoch 99/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0112 - val_loss: 0.0097
# Epoch 100/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0112 - val_loss: 0.0092
# Epoch 101/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0116 - val_loss: 0.0105
# Epoch 102/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 0.0111 - val_loss: 0.0078
# Epoch 103/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0119 - val_loss: 0.0074
# Epoch 104/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0110 - val_loss: 0.0111
# Epoch 105/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - loss: 0.0109 - val_loss: 0.0074
# Epoch 106/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0106 - val_loss: 0.0070
# Epoch 107/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0102 - val_loss: 0.0069
# Epoch 108/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0103 - val_loss: 0.0076
# Epoch 109/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0102 - val_loss: 0.0072
# Epoch 110/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0110 - val_loss: 0.0071
# Epoch 111/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0105 - val_loss: 0.0070
# Epoch 112/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0116 - val_loss: 0.0108
# Epoch 113/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0102 - val_loss: 0.0068
# Epoch 114/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0105 - val_loss: 0.0068
# Epoch 115/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0105 - val_loss: 0.0070
# Epoch 116/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0111 - val_loss: 0.0074
# Epoch 117/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0111 - val_loss: 0.0070
# Epoch 118/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0116 - val_loss: 0.0071
# Epoch 119/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0104 - val_loss: 0.0069
# Epoch 120/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0104 - val_loss: 0.0071
# Epoch 121/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0101 - val_loss: 0.0073
# Epoch 122/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0095 - val_loss: 0.0068
# Epoch 123/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0103 - val_loss: 0.0069
# Epoch 124/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0106 - val_loss: 0.0077
# Epoch 125/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0102 - val_loss: 0.0070
# Epoch 126/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0106 - val_loss: 0.0067
# Epoch 127/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0102 - val_loss: 0.0079
# Epoch 128/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0100 - val_loss: 0.0079
# Epoch 129/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0106 - val_loss: 0.0069
# Epoch 130/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0107 - val_loss: 0.0070
# Epoch 131/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0103 - val_loss: 0.0075
# Epoch 132/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0104 - val_loss: 0.0078
# Epoch 133/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0104 - val_loss: 0.0067
# Epoch 134/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0096 - val_loss: 0.0074
# Epoch 135/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0104 - val_loss: 0.0066
# Epoch 136/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0104 - val_loss: 0.0069
# Epoch 137/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0104 - val_loss: 0.0069
# Epoch 138/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0097 - val_loss: 0.0075
# Epoch 139/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0099 - val_loss: 0.0080
# Epoch 140/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0097 - val_loss: 0.0066
# Epoch 141/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0102 - val_loss: 0.0076
# Epoch 142/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0115 - val_loss: 0.0078
# Epoch 143/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0104 - val_loss: 0.0070
# Epoch 144/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0095 - val_loss: 0.0067
# Epoch 145/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0097 - val_loss: 0.0078
# Epoch 146/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0102 - val_loss: 0.0079
# Epoch 147/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 0.0102 - val_loss: 0.0066
# Epoch 148/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0106 - val_loss: 0.0069
# Epoch 149/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0104 - val_loss: 0.0070
# Epoch 150/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 0.0111 - val_loss: 0.0086
# Epoch 151/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0100 - val_loss: 0.0078
# Epoch 152/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0106 - val_loss: 0.0098
# Epoch 153/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0100 - val_loss: 0.0068
# Epoch 154/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0103 - val_loss: 0.0070
# Epoch 155/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0098 - val_loss: 0.0065
# Epoch 156/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.0103 - val_loss: 0.0071
# Epoch 157/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0099 - val_loss: 0.0074
# Epoch 158/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0106 - val_loss: 0.0069
# Epoch 159/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0102 - val_loss: 0.0074
# Epoch 160/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0104 - val_loss: 0.0078
# Epoch 161/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0098 - val_loss: 0.0066
# Epoch 162/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0095 - val_loss: 0.0082
# Epoch 163/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0107 - val_loss: 0.0069
# Epoch 164/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0120 - val_loss: 0.0066
# Epoch 165/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0104 - val_loss: 0.0067
# Epoch 166/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0104 - val_loss: 0.0070
# Epoch 167/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.0103 - val_loss: 0.0077
# Epoch 168/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0105 - val_loss: 0.0069
# Epoch 169/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0102 - val_loss: 0.0065
# Epoch 170/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0099 - val_loss: 0.0073
# Epoch 171/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0106 - val_loss: 0.0083
# Epoch 172/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0104 - val_loss: 0.0071
# Epoch 173/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0107 - val_loss: 0.0071
# Epoch 174/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0106 - val_loss: 0.0078
# Epoch 175/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0103 - val_loss: 0.0066
# Epoch 176/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0104 - val_loss: 0.0068
# Epoch 177/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0104 - val_loss: 0.0086
# Epoch 178/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0099 - val_loss: 0.0067
# Epoch 179/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0106 - val_loss: 0.0081
# Epoch 180/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 181/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0126 - val_loss: 0.0067
# Epoch 182/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0105 - val_loss: 0.0064
# Epoch 183/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0094 - val_loss: 0.0069
# Epoch 184/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0098 - val_loss: 0.0070
# Epoch 185/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0091 - val_loss: 0.0065
# Epoch 186/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 0.0098 - val_loss: 0.0064
# Epoch 187/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0098 - val_loss: 0.0069
# Epoch 188/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 0.0102 - val_loss: 0.0101
# Epoch 189/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0106 - val_loss: 0.0072
# Epoch 190/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.0105 - val_loss: 0.0078
# Epoch 191/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0098 - val_loss: 0.0073
# Epoch 192/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0100 - val_loss: 0.0066
# Epoch 193/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0107 - val_loss: 0.0068
# Epoch 194/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.0103 - val_loss: 0.0068
# Epoch 195/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0104 - val_loss: 0.0089
# Epoch 196/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.0102 - val_loss: 0.0068
# Epoch 197/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0101 - val_loss: 0.0067
# Epoch 198/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0100 - val_loss: 0.0068
# Epoch 199/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0097 - val_loss: 0.0067
# Epoch 200/200
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0117 - val_loss: 0.0071
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ### testing

# %%
# loading the model
RUL_model = load_model(f'/content/drive/MyDrive/TProject/models/RUL_{MODEL_ARCHITECTURE}.h5')
RUL_model.summary()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 3, 1)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 3, 200)         │       161,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 3, 200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 3, 200)         │       320,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 3, 200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_8 (LSTM)                   │ (None, 200)            │       320,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 50)             │        10,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 813,303 (3.10 MB)
#  Trainable params: 813,301 (3.10 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 2 (12.00 B)

# %%
# testing the model on test dataset
predicted_y = RUL_model.predict(X_RUL_test)
true_y = y_RUL_test

mse = mean_squared_error(true_y, predicted_y)
mae = mean_absolute_error(true_y, predicted_y)
rmse = np.sqrt(mse)

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)

plt.figure(figsize=(10, 5))

plt.plot(true_y, label='True Values')

plt.plot(predicted_y, label='Predicted Values')

plt.title('Comparison of True and Predicted Values Testing set')
plt.xlabel('Index')
plt.ylabel('RUL')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Mean Squared Error: 0.009649187635044895
# Mean Absolute Error: 0.07647551189617305
# Root Mean Squared Error: 0.0982302786061655

# %%
# testing the model on train dataset
predicted_y = RUL_model.predict(X_RUL_train)
true_y = y_RUL_train

mse = mean_squared_error(true_y, predicted_y)
mae = mean_absolute_error(true_y, predicted_y)
rmse = np.sqrt(mse)

print("Mean Squared Error:", mse)
print("Mean Absolute Error:", mae)
print("Root Mean Squared Error:", rmse)

plt.figure(figsize=(10, 5))

plt.plot(true_y, label='True Values')

plt.plot(predicted_y, label='Predicted Values')

plt.title('Comparison of True and Predicted Values Training set')
plt.xlabel('Index')
plt.ylabel('RUL')
plt.legend()
plt.show()
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# Mean Squared Error: 0.00800330875334464
# Mean Absolute Error: 0.07251085999044804
# Root Mean Squared Error: 0.08946121368137502

# %% [markdown]
# **Comparison between LSTM and TCN**

# %%
from tensorflow.keras.models import load_model
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import pandas as pd
import numpy as np

def evaluate_model(model_path, X_test, y_test):
    model = load_model(model_path)

    y_pred = model.predict(X_test, verbose=0)

    mae = mean_absolute_error(y_test, y_pred)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)

    return {
        "Model": model_path.replace(".h5", ""),
        "MAE": mae,
        "RMSE": rmse,
        "R2": r2
    }

# %% [markdown]
# **Capacity Models**

# %%
capacity_results = []

capacity_results.append(
    evaluate_model(
        "/content/drive/MyDrive/TProject/models/Raw_Capacity_LSTM.h5",
        X_capacity_test,
        y_capacity_test
    )
)

capacity_results.append(
    evaluate_model(
        "/content/drive/MyDrive/TProject/models/Raw_Capacity_TCN.h5",
        X_capacity_test,
        y_capacity_test
    )
)

capacity_df = pd.DataFrame(capacity_results)
print(capacity_df)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#                                                Model       MAE      RMSE  \
# 0  /content/drive/MyDrive/TProject/models/Raw_Cap...  0.089233  0.112442
# 1  /content/drive/MyDrive/TProject/models/Raw_Cap...  0.129762  0.154835
#
#          R2
# 0  0.645411
# 1  0.327641

# %% [markdown]
# **SOH Models**

# %%
soh_results = []

soh_results.append(
    evaluate_model(
        "/content/drive/MyDrive/TProject/models/SOH_LSTM.h5",
        X_SOH_test,
        y_SOH_test
    )
)

soh_results.append(
    evaluate_model(
        "/content/drive/MyDrive/TProject/models/SOH_TCN.h5",
        X_SOH_test,
        y_SOH_test
    )
)

soh_df = pd.DataFrame(soh_results)
print(soh_df)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#                                              Model       MAE      RMSE  \
# 0  /content/drive/MyDrive/TProject/models/SOH_LSTM  0.077418  0.095266
# 1   /content/drive/MyDrive/TProject/models/SOH_TCN  0.089730  0.104520
#
#          R2
# 0  0.193096
# 1  0.028730

# %% [markdown]
# **RUL Models**

# %%
rul_results = []

rul_results.append(
    evaluate_model(
        "/content/drive/MyDrive/TProject/models/RUL_LSTM.h5",
        X_RUL_test,
        y_RUL_test
    )
)

rul_results.append(
    evaluate_model(
        "/content/drive/MyDrive/TProject/models/RUL_TCN.h5",
        X_RUL_test,
        y_RUL_test
    )
)

rul_df = pd.DataFrame(rul_results)
print(rul_df)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
#                                              Model       MAE      RMSE  \
# 0  /content/drive/MyDrive/TProject/models/RUL_LSTM  0.076476  0.098230
# 1   /content/drive/MyDrive/TProject/models/RUL_TCN  0.121709  0.146905
#
#          R2
# 0  0.857193
# 1  0.680600

# %% [markdown]
# **Combined Summary**

# %%
comparison_df = pd.concat(
    [capacity_df, soh_df, rul_df],
    ignore_index=True
)

comparison_df = comparison_df.round(5)

print(comparison_df)

comparison_df.to_csv(
    "model_comparison.csv",
    index=False
)
# Out:
#                                                Model      MAE     RMSE  \
# 0  /content/drive/MyDrive/TProject/models/Raw_Cap...  0.08923  0.11244
# 1  /content/drive/MyDrive/TProject/models/Raw_Cap...  0.12976  0.15483
# 2    /content/drive/MyDrive/TProject/models/SOH_LSTM  0.07742  0.09527
# 3     /content/drive/MyDrive/TProject/models/SOH_TCN  0.08973  0.10452
# 4    /content/drive/MyDrive/TProject/models/RUL_LSTM  0.07648  0.09823
# 5     /content/drive/MyDrive/TProject/models/RUL_TCN  0.12171  0.14691
#
#         R2
# 0  0.64541
# 1  0.32764
# 2  0.19310
# 3  0.02873
# 4  0.85719
# 5  0.68060
